# %% [markdown]
# <a href="https://colab.research.google.com/github/devd-09/Gee_Projects/blob/main/Debayan_Cluster_marker_interactive_map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install leafmap (uncomment if you have not installed leafmap library before)
import leafmap

# %%
vis_map= leafmap.Map()
path_csv="https://raw.githubusercontent.com/devd-09/Gee_Projects/refs/heads/main/places_of_worship_MP.csv"
vis_map.add_basemap("HYBRID")
vis_map.add_points_from_xy(path_csv, x="shape@x", y="shape@y", layer_name="Places of Worships in Madhya Pradesh")
vis_map
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…
